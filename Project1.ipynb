# %% [markdown]
# # FIRST PROJECT

# %% [markdown]
# ## Muhammad Bilal Naseer <br>202046892

# %% [markdown]
# ## Explanation
# I worked alone on this project. I want to mention that on the first glance it looks like that there are more the 3 visualization but I want to explainn there are just 3. I created one visualization as 2 so that I can better integrate it into my infographic.
#
# I created an additional .csv file and some pictures and icons were also used in this project that am attaching as a zip folder so that you can have access to those as well.

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('tely10.csv')
df2 = pd.read_csv('FemaleData.csv')
counts_df = df.groupby(['year']).size().reset_index(name='count')
counts_d = df.groupby('year')['city'].nunique().reset_index(name='cities_count')

# %% [markdown]
# ## Visualization 1

# %%
import folium

# Create a map object centered around St. John's, NL
st_johns_map = folium.Map(location=[47.5615, -52.7126], zoom_start=12, tiles= 'CartoDB positron', fill_opacity=0.0)

icon_filename = 'Start.png'
icon_filename3 = 'Finish.png'
icon_filename2 = 'trophy.png'

# Define the coordinates for the Tely 10 race route (replace with actual coordinates)
race_route_coords = [
    [47.528198, -52.877423],
    [47.527683, -52.873597],
    [47.528255, -52.871454],
    [47.530918, -52.867082],
    [47.531743, -52.862960],
    [47.531510, -52.858045],
    [47.534602, -52.849203],
    [47.534728, -52.845822],
    [47.532572, -52.835231],
    [47.530440, -52.830056],
    [47.527136, -52.820716],
    [47.525193, -52.809508],
    [47.523969, -52.805175],
    [47.524096, -52.797161],
    [47.524537, -52.793331],
    [47.523150, -52.778145],
    [47.524890, -52.770056],
    [47.526253, -52.767235],
    [47.527703, -52.762323],
    [47.530541, -52.757428],
    [47.536973, -52.741027],
    [47.540101, -52.737590],
    [47.542017, -52.735498],
    [47.547313, -52.731818],
    [47.549936, -52.726887],
    [47.549936, -52.727017],
    [47.558337, -52.719851],
    [47.564296, -52.714816],
    [47.565268, -52.711994],
    [47.566830, -52.710330],
    [47.567200, -52.709518],
    [47.568912, -52.708239],
    [47.570957, -52.705960],
    [47.572259, -52.707527]
]

# Add the polyline representing the race route to the map
folium.PolyLine(locations=race_route_coords, color='green', weight=5).add_to(st_johns_map)
folium.Marker(location=[47.528149, -52.875573], popup='Start Point', icon=folium.CustomIcon(icon_image=icon_filename)).add_to(st_johns_map)
folium.Marker(location=[47.572275, -52.706764], popup='End Point', icon=folium.CustomIcon(icon_image=icon_filename3)).add_to(st_johns_map)


# Display the map
st_johns_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Visualization 2

# %%
import matplotlib.pyplot as plt

# Load your background image
background_img = plt.imread('blackbackground.jpeg')

# Get the dimensions of the image
height, width, _  = background_img.shape

# Create a figure
plt.figure(figsize=(20, 12), facecolor='black')  # Adjust figure size based on image dimensions

# Plot the background image as the figure background
plt.imshow(background_img, extent=[2004, width*7.344, 1300, height*26], aspect='auto', alpha=0.8)  # Adjust alpha as needed

# Plot your data on top of the background image
plt.plot(counts_df['year'], counts_df['count'], marker='o', linestyle='-', color='yellow')

city_counts_by_year = df.groupby('year')['city'].nunique()



plt.text(0.65, 0.96, 'Number of Participants', ha='left', va='center',weight='bold', fontsize=34,color='white', transform=plt.gca().transAxes)

plt.text(0.999, 0.835, '4000-', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.999, 0.665, '3500-', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.999, 0.495, '3000-', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.999, 0.325, '2500-', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.999, 0.155, '2000-', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)

plt.text(0.03, 0.01, '2005', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.095, 0.01, '2006', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.160, 0.01, '2007', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.225, 0.01, '2008', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.290, 0.01, '2009', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.355, 0.01, '2010', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.420, 0.01, '2011', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.485, 0.01, '2012', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.550, 0.01, '2013', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.615, 0.01, '2014', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.680, 0.01, '2015', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.745, 0.01, '2016', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.810, 0.01, '2017', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.875, 0.01, '2018', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.940, 0.01, '2019', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)



plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

plt.yticks([])
plt.xticks([])

plt.show()

# %% [markdown]
# ## Visualization Practice

# %%
year = counts_d.iloc[:, 0]
cities = counts_d.iloc[:, 1]

plt.figure(figsize=(20, 12), facecolor='black')

# Plotting the data
background_img = plt.imread('blackbackground.jpeg')

# Get the dimensions of the image
height, width, _  = background_img.shape

plt.imshow(background_img, extent=[2004, width*7.344, 150, height*2], aspect='auto', alpha=0.8)  # Adjust alpha as needed
plt.plot(year, cities, marker = 'o', color='skyblue')
plt.gca().yaxis.tick_right()


# Remove borders
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)


plt.text(0.45, 0.99, 'Participants from Different Cities', ha='left', va='center',weight='bold', fontsize=34,color='white', transform=plt.gca().transAxes)


plt.text(0.999, 0.945, '370-', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.999, 0.825, '340-', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.999, 0.705, '310-', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.999, 0.585, '280-', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.999, 0.465, '250-', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.999, 0.345, '220-', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.999, 0.225, '190-', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.999, 0.105, '160-', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)

plt.text(0.03, 0.001, '2005', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.095, 0.001, '2006', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.160, 0.001, '2007', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.225, 0.001, '2008', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.290, 0.001, '2009', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.355, 0.001, '2010', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.420, 0.001, '2011', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.485, 0.001, '2012', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.550, 0.001, '2013', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.615, 0.001, '2014', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.680, 0.001, '2015', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.745, 0.001, '2016', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.810, 0.001, '2017', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.875, 0.001, '2018', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)
plt.text(0.940, 0.001, '2019', ha='left', va='center',weight='bold', fontsize=19,color='white', transform=plt.gca().transAxes)

plt.show()

# %% [markdown]
# ## Practice

# %%
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import numpy as np


#Female
F_rows_with_overall_place_1 = df2[df2['position'] == 1]
F_rows_with_overall_place_2 = df2[df2['position'] == 2]
F_rows_with_overall_place_3 = df2[df2['position'] == 3]
F_rows_with_overall_place_1 = F_rows_with_overall_place_1[['year', 'name']].set_index('year',drop=True)
F_rows_with_overall_place_2 = F_rows_with_overall_place_2[['year','name']].set_index('year', drop=True)
F_rows_with_overall_place_3 = F_rows_with_overall_place_3[['year','name']].set_index('year',drop=True)


#Male
rows_with_overall_place_1 = df[df['overall_place'] == 1]
rows_with_overall_place_2 = df[df['overall_place'] == 2]
rows_with_overall_place_3 = df[df['overall_place'] == 3]
rows_with_overall_place_1 = rows_with_overall_place_1[['year', 'name']].set_index('year',drop=True)
rows_with_overall_place_2 = rows_with_overall_place_2[['year','name']].set_index('year', drop=True)
rows_with_overall_place_3 = rows_with_overall_place_3[['year','name']].set_index('year',drop=True)


# Load your background image
background_img = plt.imread('background.png')

# Get the dimensions of the image
height, width, _ = background_img.shape

# Create a figure
plt.figure(figsize=(25, 12))  # Adjust figure size based on image dimensions

# Plot the background image as the figure background
plt.imshow(background_img, extent=[-1, 5, 0, 120], aspect='auto', alpha=1.0)  # Adjust alpha as needed

# Data for the bar plot
values = [75, 65, 55]
F_values = [55, 65, 75]
bar_width = 0.65  # Adjust the width of the bars as needed
positions = np.arange(3)


# Create a bar plot with increased spacing between bars within each group
bars = plt.bar(-0.60  , 75, width=bar_width, color='dodgerblue', label='1st Place')
bars = plt.bar(0.15, 65, width=bar_width, color='dodgerblue', label='2nd Place')
bars = plt.bar(0.90, 55, width=bar_width, color='dodgerblue', label='3rd Place')

bars = plt.bar(4.60  , 75, width=bar_width, color='pink', label='1st Place')
bars = plt.bar(3.85, 65, width=bar_width, color='pink', label='2nd Place')
bars = plt.bar(3.10, 55, width=bar_width, color='pink', label='3rd Place')

# Add text annotations inside the bars
for i in range(3):
    # Get the corresponding 'year' and 'name' values for the current bar
    if i == 0:
        years = rows_with_overall_place_1.index.tolist()
        names = rows_with_overall_place_1['name'].tolist()
    elif i == 1:
        years = rows_with_overall_place_2.index.tolist()
        names = rows_with_overall_place_2['name'].tolist()
    else:
        years = rows_with_overall_place_3.index.tolist()
        names = rows_with_overall_place_3['name'].tolist()
    
    # Reverse the order of names and years
    names.reverse()
    years.reverse()
    
    # Calculate the y-coordinate for the first annotation
    y_offset = 5.5 * (len(names) - 1)
    
    # Add each 'name: year' as an annotation inside the bar
    for j, (year, name) in enumerate(zip(years, names)):
        annotation = f"{name}: {year}"
        plt.text(i-0.6-(i*0.25), values[i] - 5 - (3*j), annotation, ha='center', color='black', fontsize='medium', weight = 'bold')

        
#Female
# Add text annotations inside the bars
for i in range(3):
    # Get the corresponding 'year' and 'name' values for the current bar
    if i == 0:
        F_years = F_rows_with_overall_place_3.index.tolist()
        F_names = F_rows_with_overall_place_3['name'].tolist()
    elif i == 1:
        F_years = F_rows_with_overall_place_2.index.tolist()
        F_names = F_rows_with_overall_place_2['name'].tolist()
    else:
        F_years = F_rows_with_overall_place_1.index.tolist()
        F_names = F_rows_with_overall_place_1['name'].tolist()
    
    # Reverse the order of names and years
    F_names.reverse()
    F_years.reverse()
    
    # Calculate the y-coordinate for the first annotation
    y_offset = 5.5 * (len(names) - 1)
    
    # Add each 'name: year' as an annotation inside the bar
    for j, (year, name) in enumerate(zip(F_years, F_names)):
        annotation = f"{name}: {year}"
        plt.text(i+3.10-(i*0.25), F_values[i] - 5 - (3*j), annotation, ha='center', color='black', fontsize='medium', weight = 'bold')

        
plt.xticks([])
plt.yticks([])

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)



img_path = 'trophy.png'  # Replace 'your_image_path.png' with the path to your image file
img = OffsetImage(plt.imread(img_path), zoom=0.2)

#MEN
#1
ab = AnnotationBbox(img, (0.06, 0.81), xycoords='axes fraction', frameon=False)
plt.gca().add_artist(ab)
plt.text(0.044, 0.85, "12", ha='left', va='center',weight='bold', fontsize=30,color='#FFD700', transform=plt.gca().transAxes)
plt.text(0.028, 0.685, "Colin", ha='left', va='center',weight='bold', fontsize=35,color='black', transform=plt.gca().transAxes)
plt.text(0.034, 0.65, "Fewer", ha='left', va='center',weight='bold', fontsize=25,color='black', transform=plt.gca().transAxes)
#2
ab = AnnotationBbox(img, (0.187, 0.72), xycoords='axes fraction', frameon=False)
plt.gca().add_artist(ab)
plt.text(0.18, 0.755, "2", ha='left', va='center',weight='bold', fontsize=30,color='#C0C0C0', transform=plt.gca().transAxes)
plt.text(0.159, 0.595, "Matt", ha='left', va='center',weight='bold', fontsize=35,color='black', transform=plt.gca().transAxes)
plt.text(0.154, 0.56, "Loiselle", ha='left', va='center',weight='bold', fontsize=25,color='black', transform=plt.gca().transAxes)
#3
ab = AnnotationBbox(img, (0.314, 0.635), xycoords='axes fraction', frameon=False)
plt.gca().add_artist(ab)
plt.text(0.307, 0.67, "1", ha='left', va='center',weight='bold', fontsize=30,color='#CD7F32', transform=plt.gca().transAxes)
plt.text(0.28, 0.51, "Daniel", ha='left', va='center',weight='bold', fontsize=35,color='black', transform=plt.gca().transAxes)
plt.text(0.288, 0.475, "McNeil", ha='left', va='center',weight='bold', fontsize=25,color='black', transform=plt.gca().transAxes)
#Positions
plt.text(0.05, 0.02, "1st", ha='left', va='center',weight='bold', fontsize=22,color='black', transform=plt.gca().transAxes)
plt.text(0.175, 0.025, "2nd", ha='left', va='center',weight='bold', fontsize=22,color='black', transform=plt.gca().transAxes)
plt.text(0.30, 0.02, "3rd", ha='left', va='center',weight='bold', fontsize=22,color='black', transform=plt.gca().transAxes)

#WOMEN
#1
ab = AnnotationBbox(img, (0.935, 0.81), xycoords='axes fraction', frameon=False)
plt.gca().add_artist(ab)
plt.text(0.927, 0.85, "6", ha='left', va='center',weight='bold', fontsize=30,color='#FFD700', transform=plt.gca().transAxes)
plt.text(0.91, 0.685, "Lisa", ha='left', va='center',weight='bold', fontsize=35,color='black', transform=plt.gca().transAxes)
plt.text(0.906, 0.65, "Harvey", ha='left', va='center',weight='bold', fontsize=25,color='black', transform=plt.gca().transAxes)
#2
ab = AnnotationBbox(img, (0.805, 0.72), xycoords='axes fraction', frameon=False)
plt.gca().add_artist(ab)
plt.text(0.797, 0.755, "4", ha='left', va='center',weight='bold', fontsize=30,color='#C0C0C0', transform=plt.gca().transAxes)
plt.text(0.775, 0.595, "Kate", ha='left', va='center',weight='bold', fontsize=35,color='black', transform=plt.gca().transAxes)
plt.text(0.772, 0.56, "Bazeley", ha='left', va='center',weight='bold', fontsize=25,color='black', transform=plt.gca().transAxes)
#3
ab = AnnotationBbox(img, (0.675, 0.635), xycoords='axes fraction', frameon=False)
plt.gca().add_artist(ab)
plt.text(0.669, 0.67, "2", ha='left', va='center',weight='bold', fontsize=30,color='#CD7F32', transform=plt.gca().transAxes)
plt.text(0.63, 0.51, "Jennifer", ha='left', va='center',weight='bold', fontsize=35,color='black', transform=plt.gca().transAxes)
plt.text(0.648, 0.475, "Murrin", ha='left', va='center',weight='bold', fontsize=25,color='black', transform=plt.gca().transAxes)
#Positions
plt.text(0.92, 0.02, "1st", ha='left', va='center',weight='bold', fontsize=22,color='black', transform=plt.gca().transAxes)
plt.text(0.79, 0.02, "2nd", ha='left', va='center',weight='bold', fontsize=22,color='black', transform=plt.gca().transAxes)
plt.text(0.665, 0.02, "3rd", ha='left', va='center',weight='bold', fontsize=22,color='black', transform=plt.gca().transAxes)


plt.text(0.2, 0.90, "Tely 10 Mile Road Race", ha='left', va='center',weight='bold', fontsize=62,color='black', transform=plt.gca().transAxes)



# Show the plot
plt.show()

# %% [markdown]
# ## Visualization 3 (1/2)

# %%
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import numpy as np

#Male
rows_with_overall_place_1 = df[df['overall_place'] == 1]
rows_with_overall_place_2 = df[df['overall_place'] == 2]
rows_with_overall_place_3 = df[df['overall_place'] == 3]
rows_with_overall_place_1 = rows_with_overall_place_1[['year', 'name']].set_index('year',drop=True)
rows_with_overall_place_2 = rows_with_overall_place_2[['year','name']].set_index('year', drop=True)
rows_with_overall_place_3 = rows_with_overall_place_3[['year','name']].set_index('year',drop=True)


# Get the dimensions of the image
height, width, _ = background_img.shape

# Create a figure

plt.figure(figsize=(10, 18))  # Adjust figure size based on image dimensions

# Plot the background image as the figure background
#plt.imshow(background_img, extent=[-1, 5, 0, 120], aspect='auto', alpha=1.0)  # Adjust alpha as needed

# Data for the bar plot
values = [65,57.5,50]
bar_width = 0.65  # Adjust the width of the bars as needed
positions = np.arange(3)


# Create a bar plot with increased spacing between bars within each group
bars = plt.bar(-0.60  , 65, width=bar_width, color='dodgerblue', label='1st Place')
bars = plt.bar(0.15, 57.5, width=bar_width, color='dodgerblue', label='2nd Place')
bars = plt.bar(0.90, 50, width=bar_width, color='dodgerblue', label='3rd Place')


# Add text annotations inside the bars
for i in range(3):
    # Get the corresponding 'year' and 'name' values for the current bar
    if i == 0:
        years = rows_with_overall_place_1.index.tolist()
        names = rows_with_overall_place_1['name'].tolist()
    elif i == 1:
        years = rows_with_overall_place_2.index.tolist()
        names = rows_with_overall_place_2['name'].tolist()
    else:
        years = rows_with_overall_place_3.index.tolist()
        names = rows_with_overall_place_3['name'].tolist()
    
    # Reverse the order of names and years
    names.reverse()
    years.reverse()
    
    # Calculate the y-coordinate for the first annotation
    y_offset = 5.5 * (len(names) - 1)
    
    # Add each 'name: year' as an annotation inside the bar
    for j, (year, name) in enumerate(zip(years, names)):
        annotation = f"{name}: {year}"
        plt.text(i-0.6-(i*0.25), values[i] - 3 - (3*j), annotation, ha='center', color='black', fontsize='medium', weight='bold')


        
plt.xticks([])
plt.yticks([])

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)


img_path = 'trophy.png'  # Replace 'your_image_path.png' with the path to your image file
img = OffsetImage(plt.imread(img_path), zoom=0.15)

#MEN
#1
ab = AnnotationBbox(img, (0.09, 0.99), xycoords='axes fraction', frameon=False)
plt.gca().add_artist(ab)
plt.text(0.068, 1.005, "12", ha='left', va='center',weight='bold', fontsize=18,color='#FFD700', transform=plt.gca().transAxes)
plt.text(0.14, 0.99, "Colin", ha='left', va='center',weight='bold', fontsize=35,color='black', transform=plt.gca().transAxes)
plt.text(0.14, 0.965, "Fewer", ha='left', va='center',weight='bold', fontsize=25,color='black', transform=plt.gca().transAxes)
#2
ab = AnnotationBbox(img, (0.409, 0.88), xycoords='axes fraction', frameon=False)
plt.gca().add_artist(ab)
plt.text(0.40, 0.895, "2", ha='left', va='center',weight='bold', fontsize=18,color='#C0C0C0', transform=plt.gca().transAxes)
plt.text(0.46, 0.885, "Matt", ha='left', va='center',weight='bold', fontsize=35,color='black', transform=plt.gca().transAxes)
plt.text(0.46, 0.86, "Loiselle", ha='left', va='center',weight='bold', fontsize=25,color='black', transform=plt.gca().transAxes)
#3
ab = AnnotationBbox(img, (0.728, 0.77), xycoords='axes fraction', frameon=False)
plt.gca().add_artist(ab)
plt.text(0.715, 0.785, "1", ha='left', va='center',weight='bold', fontsize=18,color='#CD7F32', transform=plt.gca().transAxes)
plt.text(0.79, 0.775, "Daniel", ha='left', va='center',weight='bold', fontsize=35,color='black', transform=plt.gca().transAxes)
plt.text(0.79, 0.75, "McNeil", ha='left', va='center',weight='bold', fontsize=25,color='black', transform=plt.gca().transAxes)

#Positions
plt.text(0.145, 0.015, "1st", ha='left', va='center',weight='bold', fontsize=22,color='black', transform=plt.gca().transAxes)
plt.text(0.455, 0.015, "2nd", ha='left', va='center',weight='bold', fontsize=22,color='black', transform=plt.gca().transAxes)
plt.text(0.775, 0.015, "3rd", ha='left', va='center',weight='bold', fontsize=22,color='black', transform=plt.gca().transAxes)


# Show the plot
plt.show()

# %% [markdown]
# ## Visualization 3 (2/2)

# %%
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import numpy as np

F_rows_with_overall_place_1 = df2[df2['position'] == 1]
F_rows_with_overall_place_2 = df2[df2['position'] == 2]
F_rows_with_overall_place_3 = df2[df2['position'] == 3]
F_rows_with_overall_place_1 = F_rows_with_overall_place_1[['year', 'name']].set_index('year',drop=True)
F_rows_with_overall_place_2 = F_rows_with_overall_place_2[['year','name']].set_index('year', drop=True)
F_rows_with_overall_place_3 = F_rows_with_overall_place_3[['year','name']].set_index('year',drop=True)


# Get the dimensions of the image
height, width, _ = background_img.shape

# Create a figure

plt.figure(figsize=(10, 18))  # Adjust figure size based on image dimensions

# Plot the background image as the figure background
#plt.imshow(background_img, extent=[-1, 5, 0, 120], aspect='auto', alpha=1.0)  # Adjust alpha as needed

# Data for the bar plot
values = [65,57.5,50]
bar_width = 0.65  # Adjust the width of the bars as needed
positions = np.arange(3)


# Create a bar plot with increased spacing between bars within each group
bars = plt.bar(-0.60  , 65, width=bar_width, color='pink', label='1st Place')
bars = plt.bar(0.15, 57.5, width=bar_width, color='pink', label='2nd Place')
bars = plt.bar(0.90, 50, width=bar_width, color='pink', label='3rd Place')


# Add text annotations inside the bars
for i in range(3):
    # Get the corresponding 'year' and 'name' values for the current bar
    if i == 0:
        years = F_rows_with_overall_place_1.index.tolist()
        names = F_rows_with_overall_place_1['name'].tolist()
    elif i == 1:
        years = F_rows_with_overall_place_2.index.tolist()
        names = F_rows_with_overall_place_2['name'].tolist()
    else:
        years = F_rows_with_overall_place_3.index.tolist()
        names = F_rows_with_overall_place_3['name'].tolist()
    
    # Reverse the order of names and years
    names.reverse()
    years.reverse()
    
    # Calculate the y-coordinate for the first annotation
    y_offset = 5.5 * (len(names) - 1)
    
    # Add each 'name: year' as an annotation inside the bar
    for j, (year, name) in enumerate(zip(years, names)):
        annotation = f"{name}: {year}"
        plt.text(i-0.6-(i*0.25), values[i] - 3 - (3*j), annotation, ha='center', color='black', fontsize='medium', weight = 'bold')


        
plt.xticks([])
plt.yticks([])

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)


img_path = 'trophy.png'  # Replace 'your_image_path.png' with the path to your image file
img = OffsetImage(plt.imread(img_path), zoom=0.15)



#MEN
#1
ab = AnnotationBbox(img, (0.09, 0.99), xycoords='axes fraction', frameon=False)
plt.gca().add_artist(ab)
plt.text(0.078, 1.005, "6", ha='left', va='center',weight='bold', fontsize=18,color='#FFD700', transform=plt.gca().transAxes)
plt.text(0.14, 0.99, "Lisa", ha='left', va='center',weight='bold', fontsize=35,color='black', transform=plt.gca().transAxes)
plt.text(0.14, 0.965, "Harvey", ha='left', va='center',weight='bold', fontsize=25,color='black', transform=plt.gca().transAxes)
#2
ab = AnnotationBbox(img, (0.409, 0.88), xycoords='axes fraction', frameon=False)
plt.gca().add_artist(ab)
plt.text(0.40, 0.895, "4", ha='left', va='center',weight='bold', fontsize=18,color='#C0C0C0', transform=plt.gca().transAxes)
plt.text(0.46, 0.885, "Kate", ha='left', va='center',weight='bold', fontsize=35,color='black', transform=plt.gca().transAxes)
plt.text(0.46, 0.86, "Bazeley", ha='left', va='center',weight='bold', fontsize=25,color='black', transform=plt.gca().transAxes)
#3
ab = AnnotationBbox(img, (0.728, 0.77), xycoords='axes fraction', frameon=False)
plt.gca().add_artist(ab)
plt.text(0.715, 0.785, "2", ha='left', va='center',weight='bold', fontsize=18,color='#CD7F32', transform=plt.gca().transAxes)
plt.text(0.79, 0.775, "Jennifer", ha='left', va='center',weight='bold', fontsize=35,color='black', transform=plt.gca().transAxes)
plt.text(0.79, 0.745, "Murrin", ha='left', va='center',weight='bold', fontsize=25,color='black', transform=plt.gca().transAxes)

#Positions
plt.text(0.145, 0.015, "1st", ha='left', va='center',weight='bold', fontsize=22,color='black', transform=plt.gca().transAxes)
plt.text(0.455, 0.015, "2nd", ha='left', va='center',weight='bold', fontsize=22,color='black', transform=plt.gca().transAxes)
plt.text(0.775, 0.015, "3rd", ha='left', va='center',weight='bold', fontsize=22,color='black', transform=plt.gca().transAxes)


# Show the plot
plt.show()

# %% [markdown]
# ## Attributions
# I used the following sources:
# 1) https://www.nlaa.ca/tely10/statistics/records.php
# 2) https://matplotlib.org
# 3) https://realpython.com/python-folium-web-maps-from-data/
# 4) I also used chatgpt to better understand and refactor my code.
# 5) I also utilized lecture materials and solutions to my assignments.
